# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.DataFrame([30,20,45,48,67,57,35,45,41,75,63,56,55,49,50,53,44,63,62,34,80,62,54,55,47,68,41,59,53,48,59])

# %%
sns.distplot(data,bins=5)
